# %%
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)

import numpy
import seaborn
import pathlib
import geopandas
import pandas
import shapely
import rioxarray
import matplotlib.pyplot
from IPython.display import display, HTML

display(HTML("<style>.container { width:100% !important; }</style>"))
# Out:
# <style>.container { width:100% !important; }</style>

# %% [markdown]
# # Plan
# * Load in GeoFabrics estimated width, depth and water surface height - (using those used in GeoFabrics - i.e. same level of smoothing)
#   * Calculate channel area - assume rectangular
# * Load in measured cross sections
#   * Transform to NZVD2016
#   * Calculate the channel area - use the same water height as the GeoFabrics estimates
# * Compare the results
#   * Take the nearest GeoFabrics cross section to each measured cross section
#   * Plot area's on the same plot

# %%
resolution = 10
horizontal_crs = 2193

# %% [markdown]
# ### Load in GeoFabrics Bathymetry estimates

# %%
cache_path = pathlib.Path(r"C:\Local\data\catchments\Waikanae\caches")
folder = "paper"
dems = {}
#dems["Conceptual Multivariate Regression River"] = rioxarray.rioxarray.open_rasterio(cache_path / folder / "geofabric_4m_river.nc", masked=True).squeeze("band", drop=True)
dems["Uniform Flow River"] = rioxarray.rioxarray.open_rasterio(cache_path / folder / "geofabric_4m_neal.nc", masked=True).squeeze("band", drop=True)
#dems["Unconditioned"] = rioxarray.rioxarray.open_rasterio(cache_path / folder / "geofabric_4m_unconditioned.nc", masked=True).squeeze("band", drop=True)
dems["Riparian 1m Raw"] = rioxarray.rioxarray.open_rasterio(cache_path / folder / "river" / "raw_veg_dem.nc", masked=True).squeeze("band", drop=True)
dems["Gnd 1m Raw"] = rioxarray.rioxarray.open_rasterio(cache_path / folder / "river" / "raw_gnd_dem.nc", masked=True).squeeze("band", drop=True)

# %%
river_centreline = geopandas.read_file(cache_path / folder / "river" / r"aligned_river_centreline_100000000.geojson")
river_polygon = geopandas.read_file(cache_path / folder / "river" / "river_polygon.geojson")
fan_polygon = geopandas.read_file(cache_path / folder / "river" / "fan_polygon.geojson")

# %%
polygon = geopandas.GeoDataFrame( pandas.concat([river_polygon, fan_polygon], ignore_index=True), crs=river_polygon.crs).dissolve()

# %% [markdown]
# ## Load in sampled cross sections
# Load in the cross sections from one river generation

# %%
sampled_sections = geopandas.read_file(cache_path / folder / "river" / "final_cross_sections.geojson")
sampled_sections = sampled_sections.drop(columns=['min_z_centre', 'min_z_centre_unimodal', 'slope',
       'min_z_centre_unimodal_mean_0.05km', 'slope_mean_0.05km',
       'min_z_centre_unimodal_mean_0.25km', 'slope_mean_0.25km',
       'min_z_centre_unimodal_mean_0.5km', 'slope_mean_0.5km',
       'min_z_centre_unimodal_mean_1.0km', 'slope_mean_1.0km', 'widths',
       'threshold', 'channel_count', 'flat_widths', 'valid', 'valid_widths',
       'valid_flat_widths', 'valid_threhold', 'widths_mean_0.05km',
       'flat_widths_mean_0.05km', 'thresholds_mean_0.05km',
       'widths_mean_0.15km', 'flat_widths_mean_0.15km',
       'thresholds_mean_0.15km', 'widths_mean_0.2km', 'flat_widths_mean_0.2km',
       'thresholds_mean_0.2km', 'widths_mean_0.25km',
       'flat_widths_mean_0.25km', 'thresholds_mean_0.25km'])

# %%
widths = {}
widths["River"] = geopandas.read_file(cache_path / folder / "river" / "final_widths.geojson")
thresholds = {"Min": 0.75, "Max": 2}

# %% [markdown]
# ## Sample DEM for elevations
# Record the Bias and STDev for each cross section against the two DEMS

# %%
fig, ax = matplotlib.pyplot.subplots(ncols=1, nrows=1, figsize=(10, 5))
polygon.plot(ax=ax, color='g')
sampled_sections.plot(ax=ax)
# Out:
# <Axes: >

# %% [markdown]
# # Sample every 1m
# Use Linear interpolation in between

# %%
comparisons_sampled = {**dict((f"{key} z", []) for key in dems), **dict((f"{key} river", []) for key in widths), **{"Section": [], "Polygon": [], "Distance Upstream [m]": [], "Offset [m]": []}}
intersection_points = sampled_sections.intersection(river_centreline.iloc[0].geometry)
for index, row in sampled_sections.iterrows():
    print(f"Section number = {index} of {len(sampled_sections)}")
    line = row.geometry
    distance_upstream = float(river_centreline.project(intersection_points.iloc[index]))
    for offset in list(range(int(numpy.ceil(line.length)))):
        point = line.interpolate(offset)
        for key in dems:
            comparisons_sampled[f"{key} z"].append(float(dems[key].z.interp(x=point.x, y=point.y)))
        for key in widths:
            if widths[key].iloc[index].geometry is not None:
                comparisons_sampled[f"{key} river"].append(widths[key].iloc[index].geometry.distance(point) < 0.001)
            else:
                comparisons_sampled[f"{key} river"].append(False)
        comparisons_sampled["Section"].append(index)
        comparisons_sampled["Polygon"].append(polygon.iloc[0].geometry.contains(point))
        comparisons_sampled["Distance Upstream [m]"].append(distance_upstream)
        comparisons_sampled["Offset [m]"].append(offset)
comparisons_sampled = pandas.DataFrame.from_dict(comparisons_sampled)
# Out:
# Section number = 0 of 947
# Section number = 1 of 947
# Section number = 2 of 947
# Section number = 3 of 947
# Section number = 4 of 947
# Section number = 5 of 947
# Section number = 6 of 947
# Section number = 7 of 947
# Section number = 8 of 947
# Section number = 9 of 947
# Section number = 10 of 947
# Section number = 11 of 947
# Section number = 12 of 947
# Section number = 13 of 947
# Section number = 14 of 947
# Section number = 15 of 947
# Section number = 16 of 947
# Section number = 17 of 947
# Section number = 18 of 947
# Section number = 19 of 947
# Section number = 20 of 947
# Section number = 21 of 947
# Section number = 22 of 947
# Section number = 23 of 947
# Section number = 24 of 947
# Section number = 25 of 947
# Section number = 26 of 947
# Section number = 27 of 947
# Section number = 28 of 947
# Section number = 29 of 947
# Section number = 30 of 947
# Section number = 31 of 947
# Section number = 32 of 947
# Section number = 33 of 947
# Section number = 34 of 947
# Section number = 35 of 947
# Section number = 36 of 947
# Section number = 37 of 947
# Section number = 38 of 947
# Section number = 39 of 947
# Section number = 40 of 947
# Section number = 41 of 947
# Section number = 42 of 947
# Section number = 43 of 947
# Section number = 44 of 947
# Section number = 45 of 947
# Section number = 46 of 947
# Section number = 47 of 947
# Section number = 48 of 947
# Section number = 49 of 947
# Section number = 50 of 947
# Section number = 51 of 947
# Section number = 52 of 947
# Section number = 53 of 947
# Section number = 54 of 947
# Section number = 55 of 947
# Section number = 56 of 947
# Section number = 57 of 947
# Section number = 58 of 947
# Section number = 59 of 947
# Section number = 60 of 947
# Section number = 61 of 947
# Section number = 62 of 947
# Section number = 63 of 947
# Section number = 64 of 947
# Section number = 65 of 947
# Section number = 66 of 947
# Section number = 67 of 947
# Section number = 68 of 947
# Section number = 69 of 947
# Section number = 70 of 947
# Section number = 71 of 947
# Section number = 72 of 947
# Section number = 73 of 947
# Section number = 74 of 947
# Section number = 75 of 947
# Section number = 76 of 947
# Section number = 77 of 947
# Section number = 78 of 947
# Section number = 79 of 947
# Section number = 80 of 947
# Section number = 81 of 947
# Section number = 82 of 947
# Section number = 83 of 947
# Section number = 84 of 947
# Section number = 85 of 947
# Section number = 86 of 947
# Section number = 87 of 947
# Section number = 88 of 947
# Section number = 89 of 947
# Section number = 90 of 947
# Section number = 91 of 947
# Section number = 92 of 947
# Section number = 93 of 947
# Section number = 94 of 947
# Section number = 95 of 947
# Section number = 96 of 947
# Section number = 97 of 947
# Section number = 98 of 947
# Section number = 99 of 947
# Section number = 100 of 947
# Section number = 101 of 947
# Section number = 102 of 947
# Section number = 103 of 947
# Section number = 104 of 947
# Section number = 105 of 947
# Section number = 106 of 947
# Section number = 107 of 947
# Section number = 108 of 947
# Section number = 109 of 947
# Section number = 110 of 947
# Section number = 111 of 947
# Section number = 112 of 947
# Section number = 113 of 947
# Section number = 114 of 947
# Section number = 115 of 947
# Section number = 116 of 947
# Section number = 117 of 947
# Section number = 118 of 947
# Section number = 119 of 947
# Section number = 120 of 947
# Section number = 121 of 947
# Section number = 122 of 947
# Section number = 123 of 947
# Section number = 124 of 947
# Section number = 125 of 947
# Section number = 126 of 947
# Section number = 127 of 947
# Section number = 128 of 947
# Section number = 129 of 947
# Section number = 130 of 947
# Section number = 131 of 947
# Section number = 132 of 947
# Section number = 133 of 947
# Section number = 134 of 947
# Section number = 135 of 947
# Section number = 136 of 947
# Section number = 137 of 947
# Section number = 138 of 947
# Section number = 139 of 947
# Section number = 140 of 947
# Section number = 141 of 947
# Section number = 142 of 947
# Section number = 143 of 947
# Section number = 144 of 947
# Section number = 145 of 947
# Section number = 146 of 947
# Section number = 147 of 947
# Section number = 148 of 947
# Section number = 149 of 947
# Section number = 150 of 947
# Section number = 151 of 947
# Section number = 152 of 947
# Section number = 153 of 947
# Section number = 154 of 947
# Section number = 155 of 947
# Section number = 156 of 947
# Section number = 157 of 947
# Section number = 158 of 947
# Section number = 159 of 947
# Section number = 160 of 947
# Section number = 161 of 947
# Section number = 162 of 947
# Section number = 163 of 947
# Section number = 164 of 947
# Section number = 165 of 947
# Section number = 166 of 947
# Section number = 167 of 947
# Section number = 168 of 947
# Section number = 169 of 947
# Section number = 170 of 947
# Section number = 171 of 947
# Section number = 172 of 947
# Section number = 173 of 947
# Section number = 174 of 947
# Section number = 175 of 947
# Section number = 176 of 947
# Section number = 177 of 947
# Section number = 178 of 947
# Section number = 179 of 947
# Section number = 180 of 947
# Section number = 181 of 947
# Section number = 182 of 947
# Section number = 183 of 947
# Section number = 184 of 947
# Section number = 185 of 947
# Section number = 186 of 947
# Section number = 187 of 947
# Section number = 188 of 947
# Section number = 189 of 947
# Section number = 190 of 947
# Section number = 191 of 947
# Section number = 192 of 947
# Section number = 193 of 947
# Section number = 194 of 947
# Section number = 195 of 947
# Section number = 196 of 947
# Section number = 197 of 947
# Section number = 198 of 947
# Section number = 199 of 947
# Section number = 200 of 947
# Section number = 201 of 947
# Section number = 202 of 947
# Section number = 203 of 947
# Section number = 204 of 947
# Section number = 205 of 947
# Section number = 206 of 947
# Section number = 207 of 947
# Section number = 208 of 947
# Section number = 209 of 947
# Section number = 210 of 947
# Section number = 211 of 947
# Section number = 212 of 947
# Section number = 213 of 947
# Section number = 214 of 947
# Section number = 215 of 947
# Section number = 216 of 947
# Section number = 217 of 947
# Section number = 218 of 947
# Section number = 219 of 947
# Section number = 220 of 947
# Section number = 221 of 947
# Section number = 222 of 947
# Section number = 223 of 947
# Section number = 224 of 947
# Section number = 225 of 947
# Section number = 226 of 947
# Section number = 227 of 947
# Section number = 228 of 947
# Section number = 229 of 947
# Section number = 230 of 947
# Section number = 231 of 947
# Section number = 232 of 947
# Section number = 233 of 947
# Section number = 234 of 947
# Section number = 235 of 947
# Section number = 236 of 947
# Section number = 237 of 947
# Section number = 238 of 947
# Section number = 239 of 947
# Section number = 240 of 947
# Section number = 241 of 947
# Section number = 242 of 947
# Section number = 243 of 947
# Section number = 244 of 947
# Section number = 245 of 947
# Section number = 246 of 947
# Section number = 247 of 947
# Section number = 248 of 947
# Section number = 249 of 947
# Section number = 250 of 947
# Section number = 251 of 947
# Section number = 252 of 947
# Section number = 253 of 947
# Section number = 254 of 947
# Section number = 255 of 947
# Section number = 256 of 947
# Section number = 257 of 947
# Section number = 258 of 947
# Section number = 259 of 947
# Section number = 260 of 947
# Section number = 261 of 947
# Section number = 262 of 947
# Section number = 263 of 947
# Section number = 264 of 947
# Section number = 265 of 947
# Section number = 266 of 947
# Section number = 267 of 947
# Section number = 268 of 947
# Section number = 269 of 947
# Section number = 270 of 947
# Section number = 271 of 947
# Section number = 272 of 947
# Section number = 273 of 947
# Section number = 274 of 947
# Section number = 275 of 947
# Section number = 276 of 947
# Section number = 277 of 947
# Section number = 278 of 947
# Section number = 279 of 947
# Section number = 280 of 947
# Section number = 281 of 947
# Section number = 282 of 947
# Section number = 283 of 947
# Section number = 284 of 947
# Section number = 285 of 947
# Section number = 286 of 947
# Section number = 287 of 947
# Section number = 288 of 947
# Section number = 289 of 947
# Section number = 290 of 947
# Section number = 291 of 947
# Section number = 292 of 947
# Section number = 293 of 947
# Section number = 294 of 947
# Section number = 295 of 947
# Section number = 296 of 947
# Section number = 297 of 947
# Section number = 298 of 947
# Section number = 299 of 947
# Section number = 300 of 947
# Section number = 301 of 947
# Section number = 302 of 947
# Section number = 303 of 947
# Section number = 304 of 947
# Section number = 305 of 947
# Section number = 306 of 947
# Section number = 307 of 947
# Section number = 308 of 947
# Section number = 309 of 947
# Section number = 310 of 947
# Section number = 311 of 947
# Section number = 312 of 947
# Section number = 313 of 947
# Section number = 314 of 947
# Section number = 315 of 947
# Section number = 316 of 947
# Section number = 317 of 947
# Section number = 318 of 947
# Section number = 319 of 947
# Section number = 320 of 947
# Section number = 321 of 947
# Section number = 322 of 947
# Section number = 323 of 947
# Section number = 324 of 947
# Section number = 325 of 947
# Section number = 326 of 947
# Section number = 327 of 947
# Section number = 328 of 947
# Section number = 329 of 947
# Section number = 330 of 947
# Section number = 331 of 947
# Section number = 332 of 947
# Section number = 333 of 947
# Section number = 334 of 947
# Section number = 335 of 947
# Section number = 336 of 947
# Section number = 337 of 947
# Section number = 338 of 947
# Section number = 339 of 947
# Section number = 340 of 947
# Section number = 341 of 947
# Section number = 342 of 947
# Section number = 343 of 947
# Section number = 344 of 947
# Section number = 345 of 947
# Section number = 346 of 947
# Section number = 347 of 947
# Section number = 348 of 947
# Section number = 349 of 947
# Section number = 350 of 947
# Section number = 351 of 947
# Section number = 352 of 947
# Section number = 353 of 947
# Section number = 354 of 947
# Section number = 355 of 947
# Section number = 356 of 947
# Section number = 357 of 947
# Section number = 358 of 947
# Section number = 359 of 947
# Section number = 360 of 947
# Section number = 361 of 947
# Section number = 362 of 947
# Section number = 363 of 947
# Section number = 364 of 947
# Section number = 365 of 947
# Section number = 366 of 947
# Section number = 367 of 947
# Section number = 368 of 947
# Section number = 369 of 947
# Section number = 370 of 947
# Section number = 371 of 947
# Section number = 372 of 947
# Section number = 373 of 947
# Section number = 374 of 947
# Section number = 375 of 947
# Section number = 376 of 947
# Section number = 377 of 947
# Section number = 378 of 947
# Section number = 379 of 947
# Section number = 380 of 947
# Section number = 381 of 947
# Section number = 382 of 947
# Section number = 383 of 947
# Section number = 384 of 947
# Section number = 385 of 947
# Section number = 386 of 947
# Section number = 387 of 947
# Section number = 388 of 947
# Section number = 389 of 947
# Section number = 390 of 947
# Section number = 391 of 947
# Section number = 392 of 947
# Section number = 393 of 947
# Section number = 394 of 947
# Section number = 395 of 947
# Section number = 396 of 947
# Section number = 397 of 947
# Section number = 398 of 947
# Section number = 399 of 947
# Section number = 400 of 947
# Section number = 401 of 947
# Section number = 402 of 947
# Section number = 403 of 947
# Section number = 404 of 947
# Section number = 405 of 947
# Section number = 406 of 947
# Section number = 407 of 947
# Section number = 408 of 947
# Section number = 409 of 947
# Section number = 410 of 947
# Section number = 411 of 947
# Section number = 412 of 947
# Section number = 413 of 947
# Section number = 414 of 947
# Section number = 415 of 947
# Section number = 416 of 947
# Section number = 417 of 947
# Section number = 418 of 947
# Section number = 419 of 947
# Section number = 420 of 947
# Section number = 421 of 947
# Section number = 422 of 947
# Section number = 423 of 947
# Section number = 424 of 947
# Section number = 425 of 947
# Section number = 426 of 947
# Section number = 427 of 947
# Section number = 428 of 947
# Section number = 429 of 947
# Section number = 430 of 947
# Section number = 431 of 947
# Section number = 432 of 947
# Section number = 433 of 947
# Section number = 434 of 947
# Section number = 435 of 947
# Section number = 436 of 947
# Section number = 437 of 947
# Section number = 438 of 947
# Section number = 439 of 947
# Section number = 440 of 947
# Section number = 441 of 947
# Section number = 442 of 947
# Section number = 443 of 947
# Section number = 444 of 947
# Section number = 445 of 947
# Section number = 446 of 947
# Section number = 447 of 947
# Section number = 448 of 947
# Section number = 449 of 947
# Section number = 450 of 947
# Section number = 451 of 947
# Section number = 452 of 947
# Section number = 453 of 947
# Section number = 454 of 947
# Section number = 455 of 947
# Section number = 456 of 947
# Section number = 457 of 947
# Section number = 458 of 947
# Section number = 459 of 947
# Section number = 460 of 947
# Section number = 461 of 947
# Section number = 462 of 947
# Section number = 463 of 947
# Section number = 464 of 947
# Section number = 465 of 947
# Section number = 466 of 947
# Section number = 467 of 947
# Section number = 468 of 947
# Section number = 469 of 947
# Section number = 470 of 947
# Section number = 471 of 947
# Section number = 472 of 947
# Section number = 473 of 947
# Section number = 474 of 947
# Section number = 475 of 947
# Section number = 476 of 947
# Section number = 477 of 947
# Section number = 478 of 947
# Section number = 479 of 947
# Section number = 480 of 947
# Section number = 481 of 947
# Section number = 482 of 947
# Section number = 483 of 947
# Section number = 484 of 947
# Section number = 485 of 947
# Section number = 486 of 947
# Section number = 487 of 947
# Section number = 488 of 947
# Section number = 489 of 947
# Section number = 490 of 947
# Section number = 491 of 947
# Section number = 492 of 947
# Section number = 493 of 947
# Section number = 494 of 947
# Section number = 495 of 947
# Section number = 496 of 947
# Section number = 497 of 947
# Section number = 498 of 947
# Section number = 499 of 947
# Section number = 500 of 947
# Section number = 501 of 947
# Section number = 502 of 947
# Section number = 503 of 947
# Section number = 504 of 947
# Section number = 505 of 947
# Section number = 506 of 947
# Section number = 507 of 947
# Section number = 508 of 947
# Section number = 509 of 947
# Section number = 510 of 947
# Section number = 511 of 947
# Section number = 512 of 947
# Section number = 513 of 947
# Section number = 514 of 947
# Section number = 515 of 947
# Section number = 516 of 947
# Section number = 517 of 947
# Section number = 518 of 947
# Section number = 519 of 947
# Section number = 520 of 947
# Section number = 521 of 947
# Section number = 522 of 947
# Section number = 523 of 947
# Section number = 524 of 947
# Section number = 525 of 947
# Section number = 526 of 947
# Section number = 527 of 947
# Section number = 528 of 947
# Section number = 529 of 947
# Section number = 530 of 947
# Section number = 531 of 947
# Section number = 532 of 947
# Section number = 533 of 947
# Section number = 534 of 947
# Section number = 535 of 947
# Section number = 536 of 947
# Section number = 537 of 947
# Section number = 538 of 947
# Section number = 539 of 947
# Section number = 540 of 947
# Section number = 541 of 947
# Section number = 542 of 947
# Section number = 543 of 947
# Section number = 544 of 947
# Section number = 545 of 947
# Section number = 546 of 947
# Section number = 547 of 947
# Section number = 548 of 947
# Section number = 549 of 947
# Section number = 550 of 947
# Section number = 551 of 947
# Section number = 552 of 947
# Section number = 553 of 947
# Section number = 554 of 947
# Section number = 555 of 947
# Section number = 556 of 947
# Section number = 557 of 947
# Section number = 558 of 947
# Section number = 559 of 947
# Section number = 560 of 947
# Section number = 561 of 947
# Section number = 562 of 947
# Section number = 563 of 947
# Section number = 564 of 947
# Section number = 565 of 947
# Section number = 566 of 947
# Section number = 567 of 947
# Section number = 568 of 947
# Section number = 569 of 947
# Section number = 570 of 947
# Section number = 571 of 947
# Section number = 572 of 947
# Section number = 573 of 947
# Section number = 574 of 947
# Section number = 575 of 947
# Section number = 576 of 947
# Section number = 577 of 947
# Section number = 578 of 947
# Section number = 579 of 947
# Section number = 580 of 947
# Section number = 581 of 947
# Section number = 582 of 947
# Section number = 583 of 947
# Section number = 584 of 947
# Section number = 585 of 947
# Section number = 586 of 947
# Section number = 587 of 947
# Section number = 588 of 947
# Section number = 589 of 947
# Section number = 590 of 947
# Section number = 591 of 947
# Section number = 592 of 947
# Section number = 593 of 947
# Section number = 594 of 947
# Section number = 595 of 947
# Section number = 596 of 947
# Section number = 597 of 947
# Section number = 598 of 947
# Section number = 599 of 947
# Section number = 600 of 947
# Section number = 601 of 947
# Section number = 602 of 947
# Section number = 603 of 947
# Section number = 604 of 947
# Section number = 605 of 947
# Section number = 606 of 947
# Section number = 607 of 947
# Section number = 608 of 947
# Section number = 609 of 947
# Section number = 610 of 947
# Section number = 611 of 947
# Section number = 612 of 947
# Section number = 613 of 947
# Section number = 614 of 947
# Section number = 615 of 947
# Section number = 616 of 947
# Section number = 617 of 947
# Section number = 618 of 947
# Section number = 619 of 947
# Section number = 620 of 947
# Section number = 621 of 947
# Section number = 622 of 947
# Section number = 623 of 947
# Section number = 624 of 947
# Section number = 625 of 947
# Section number = 626 of 947
# Section number = 627 of 947
# Section number = 628 of 947
# Section number = 629 of 947
# Section number = 630 of 947
# Section number = 631 of 947
# Section number = 632 of 947
# Section number = 633 of 947
# Section number = 634 of 947
# Section number = 635 of 947
# Section number = 636 of 947
# Section number = 637 of 947
# Section number = 638 of 947
# Section number = 639 of 947
# Section number = 640 of 947
# Section number = 641 of 947
# Section number = 642 of 947
# Section number = 643 of 947
# Section number = 644 of 947
# Section number = 645 of 947
# Section number = 646 of 947
# Section number = 647 of 947
# Section number = 648 of 947
# Section number = 649 of 947
# Section number = 650 of 947
# Section number = 651 of 947
# Section number = 652 of 947
# Section number = 653 of 947
# Section number = 654 of 947
# Section number = 655 of 947
# Section number = 656 of 947
# Section number = 657 of 947
# Section number = 658 of 947
# Section number = 659 of 947
# Section number = 660 of 947
# Section number = 661 of 947
# Section number = 662 of 947
# Section number = 663 of 947
# Section number = 664 of 947
# Section number = 665 of 947
# Section number = 666 of 947
# Section number = 667 of 947
# Section number = 668 of 947
# Section number = 669 of 947
# Section number = 670 of 947
# Section number = 671 of 947
# Section number = 672 of 947
# Section number = 673 of 947
# Section number = 674 of 947
# Section number = 675 of 947
# Section number = 676 of 947
# Section number = 677 of 947
# Section number = 678 of 947
# Section number = 679 of 947
# Section number = 680 of 947
# Section number = 681 of 947
# Section number = 682 of 947
# Section number = 683 of 947
# Section number = 684 of 947
# Section number = 685 of 947
# Section number = 686 of 947
# Section number = 687 of 947
# Section number = 688 of 947
# Section number = 689 of 947
# Section number = 690 of 947
# Section number = 691 of 947
# Section number = 692 of 947
# Section number = 693 of 947
# Section number = 694 of 947
# Section number = 695 of 947
# Section number = 696 of 947
# Section number = 697 of 947
# Section number = 698 of 947
# Section number = 699 of 947
# Section number = 700 of 947
# Section number = 701 of 947
# Section number = 702 of 947
# Section number = 703 of 947
# Section number = 704 of 947
# Section number = 705 of 947
# Section number = 706 of 947
# Section number = 707 of 947
# Section number = 708 of 947
# Section number = 709 of 947
# Section number = 710 of 947
# Section number = 711 of 947
# Section number = 712 of 947
# Section number = 713 of 947
# Section number = 714 of 947
# Section number = 715 of 947
# Section number = 716 of 947
# Section number = 717 of 947
# Section number = 718 of 947
# Section number = 719 of 947
# Section number = 720 of 947
# Section number = 721 of 947
# Section number = 722 of 947
# Section number = 723 of 947
# Section number = 724 of 947
# Section number = 725 of 947
# Section number = 726 of 947
# Section number = 727 of 947
# Section number = 728 of 947
# Section number = 729 of 947
# Section number = 730 of 947
# Section number = 731 of 947
# Section number = 732 of 947
# Section number = 733 of 947
# Section number = 734 of 947
# Section number = 735 of 947
# Section number = 736 of 947
# Section number = 737 of 947
# Section number = 738 of 947
# Section number = 739 of 947
# Section number = 740 of 947
# Section number = 741 of 947
# Section number = 742 of 947
# Section number = 743 of 947
# Section number = 744 of 947
# Section number = 745 of 947
# Section number = 746 of 947
# Section number = 747 of 947
# Section number = 748 of 947
# Section number = 749 of 947
# Section number = 750 of 947
# Section number = 751 of 947
# Section number = 752 of 947
# Section number = 753 of 947
# Section number = 754 of 947
# Section number = 755 of 947
# Section number = 756 of 947
# Section number = 757 of 947
# Section number = 758 of 947
# Section number = 759 of 947
# Section number = 760 of 947
# Section number = 761 of 947
# Section number = 762 of 947
# Section number = 763 of 947
# Section number = 764 of 947
# Section number = 765 of 947
# Section number = 766 of 947
# Section number = 767 of 947
# Section number = 768 of 947
# Section number = 769 of 947
# Section number = 770 of 947
# Section number = 771 of 947
# Section number = 772 of 947
# Section number = 773 of 947
# Section number = 774 of 947
# Section number = 775 of 947
# Section number = 776 of 947
# Section number = 777 of 947
# Section number = 778 of 947
# Section number = 779 of 947
# Section number = 780 of 947
# Section number = 781 of 947
# Section number = 782 of 947
# Section number = 783 of 947
# Section number = 784 of 947
# Section number = 785 of 947
# Section number = 786 of 947
# Section number = 787 of 947
# Section number = 788 of 947
# Section number = 789 of 947
# Section number = 790 of 947
# Section number = 791 of 947
# Section number = 792 of 947
# Section number = 793 of 947
# Section number = 794 of 947
# Section number = 795 of 947
# Section number = 796 of 947
# Section number = 797 of 947
# Section number = 798 of 947
# Section number = 799 of 947
# Section number = 800 of 947
# Section number = 801 of 947
# Section number = 802 of 947
# Section number = 803 of 947
# Section number = 804 of 947
# Section number = 805 of 947
# Section number = 806 of 947
# Section number = 807 of 947
# Section number = 808 of 947
# Section number = 809 of 947
# Section number = 810 of 947
# Section number = 811 of 947
# Section number = 812 of 947
# Section number = 813 of 947
# Section number = 814 of 947
# Section number = 815 of 947
# Section number = 816 of 947
# Section number = 817 of 947
# Section number = 818 of 947
# Section number = 819 of 947
# Section number = 820 of 947
# Section number = 821 of 947
# Section number = 822 of 947
# Section number = 823 of 947
# Section number = 824 of 947
# Section number = 825 of 947
# Section number = 826 of 947
# Section number = 827 of 947
# Section number = 828 of 947
# Section number = 829 of 947
# Section number = 830 of 947
# Section number = 831 of 947
# Section number = 832 of 947
# Section number = 833 of 947
# Section number = 834 of 947
# Section number = 835 of 947
# Section number = 836 of 947
# Section number = 837 of 947
# Section number = 838 of 947
# Section number = 839 of 947
# Section number = 840 of 947
# Section number = 841 of 947
# Section number = 842 of 947
# Section number = 843 of 947
# Section number = 844 of 947
# Section number = 845 of 947
# Section number = 846 of 947
# Section number = 847 of 947
# Section number = 848 of 947
# Section number = 849 of 947
# Section number = 850 of 947
# Section number = 851 of 947
# Section number = 852 of 947
# Section number = 853 of 947
# Section number = 854 of 947
# Section number = 855 of 947
# Section number = 856 of 947
# Section number = 857 of 947
# Section number = 858 of 947
# Section number = 859 of 947
# Section number = 860 of 947
# Section number = 861 of 947
# Section number = 862 of 947
# Section number = 863 of 947
# Section number = 864 of 947
# Section number = 865 of 947
# Section number = 866 of 947
# Section number = 867 of 947
# Section number = 868 of 947
# Section number = 869 of 947
# Section number = 870 of 947
# Section number = 871 of 947
# Section number = 872 of 947
# Section number = 873 of 947
# Section number = 874 of 947
# Section number = 875 of 947
# Section number = 876 of 947
# Section number = 877 of 947
# Section number = 878 of 947
# Section number = 879 of 947
# Section number = 880 of 947
# Section number = 881 of 947
# Section number = 882 of 947
# Section number = 883 of 947
# Section number = 884 of 947
# Section number = 885 of 947
# Section number = 886 of 947
# Section number = 887 of 947
# Section number = 888 of 947
# Section number = 889 of 947
# Section number = 890 of 947
# Section number = 891 of 947
# Section number = 892 of 947
# Section number = 893 of 947
# Section number = 894 of 947
# Section number = 895 of 947
# Section number = 896 of 947
# Section number = 897 of 947
# Section number = 898 of 947
# Section number = 899 of 947
# Section number = 900 of 947
# Section number = 901 of 947
# Section number = 902 of 947
# Section number = 903 of 947
# Section number = 904 of 947
# Section number = 905 of 947
# Section number = 906 of 947
# Section number = 907 of 947
# Section number = 908 of 947
# Section number = 909 of 947
# Section number = 910 of 947
# Section number = 911 of 947
# Section number = 912 of 947
# Section number = 913 of 947
# Section number = 914 of 947
# Section number = 915 of 947
# Section number = 916 of 947
# Section number = 917 of 947
# Section number = 918 of 947
# Section number = 919 of 947
# Section number = 920 of 947
# Section number = 921 of 947
# Section number = 922 of 947
# Section number = 923 of 947
# Section number = 924 of 947
# Section number = 925 of 947
# Section number = 926 of 947
# Section number = 927 of 947
# Section number = 928 of 947
# Section number = 929 of 947
# Section number = 930 of 947
# Section number = 931 of 947
# Section number = 932 of 947
# Section number = 933 of 947
# Section number = 934 of 947
# Section number = 935 of 947
# Section number = 936 of 947
# Section number = 937 of 947
# Section number = 938 of 947
# Section number = 939 of 947
# Section number = 940 of 947
# Section number = 941 of 947
# Section number = 942 of 947
# Section number = 943 of 947
# Section number = 944 of 947
# Section number = 945 of 947
# Section number = 946 of 947

# %%
comparisons_sampled.to_json(cache_path / folder / "sampled_section_comparison" / "sampled_values.json")

# %% [markdown]
# # Plot sampled elevations along entire sections
# Plot the sampled elevations along individual cross-sections including the on-land portions as a sanity check.

# %%
comparisons_sampled.head(1)
# Out:
#    Uniform Flow River z  Riparian 1m Raw z  Gnd 1m Raw z  River river  \
# 0               1.66711            1.56231       1.56231        False
#
#    Section  Polygon  Distance Upstream [m]  Offset [m]
# 0        0    False                    0.0           0

# %%
sampled_sections.head(1)
# Out:
#    min_z_water                                           geometry
# 0    -0.235733  LINESTRING (1769112.255 5473385.987, 1769113.6...

# %%
columns = [f"{key} z" for key in dems]
for section in comparisons_sampled['Section'].unique():
    # Plot the samppled profiles
    distance = comparisons_sampled[comparisons_sampled['Section']==section]['Distance Upstream [m]'].iloc[0]
    
    # Plot sampled DEMs elevations
    axis = comparisons_sampled[comparisons_sampled["Section"]==section][columns].plot(title=f"{distance}m upstream", figsize=(15,10), linewidth=3)
    
    # Add doted lines showing where the 'water' was detected - note should all be viewed on the unconditioend DEM
    for river_name in widths:
        for dem_name in dems:
            if river_name in dem_name:
                 comparisons_sampled[(comparisons_sampled["Section"]==section) & (comparisons_sampled[f"{river_name} river"]==True)][[f"{dem_name} z"]].plot(ax=axis, linestyle=':', linewidth=4);
    
    # Plot the z_water and thresholds
    matplotlib.pyplot.axhline(y=sampled_sections.iloc[section]["min_z_water"], color='r', linestyle=':', label="min_z_water")
    for threshold_name in thresholds:
        matplotlib.pyplot.axhline(y=sampled_sections.iloc[section]["min_z_water"] + thresholds[threshold_name], color=numpy.random.rand(3,), linestyle=':', label=threshold_name)
    matplotlib.pyplot.legend()
    axis.figure.savefig(cache_path / folder / "sampled_section_comparison" / f"{distance}m_upstream.png")
    matplotlib.pyplot.close()

# %% [markdown]
# # Todo -
# 1. read in i_start & i_end
# 2. note if not valid in plot
